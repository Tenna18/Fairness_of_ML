# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
import copy

# %%
images = []
ages = []
genders = []
race = []


path_T = ''
path_L = '/Users/laurabraadrasmussen/Documents/UNI/6. semester/Bachelorprojekt/Data/UTKface_Aligned_cropped/crop_part1/'

for i in os.listdir(path_L):
    #print(i)
    split = i.split('_')
    ages.append(int(split[0]))
    genders.append(int(split[1]))
    race.append(int(split[2]))
    keep = copy.deepcopy(Image.open(path_L + i))
    images.append(keep)

# %%
images = pd.Series(list(images), name = 'Images')
ages = pd.Series(list(ages), name = 'Ages')
genders = pd.Series(list(genders), name = 'Genders')
race = pd.Series(list(race), name = 'Race')

df = pd.concat([images, ages, genders, race], axis=1)
df
# Out:
#                                                  Images  Ages  Genders  Race
# 0     <PIL.JpegImagePlugin.JpegImageFile image mode=...     9        1     2
# 1     <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     2
# 2     <PIL.JpegImagePlugin.JpegImageFile image mode=...    16        0     0
# 3     <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     3
# 4     <PIL.JpegImagePlugin.JpegImageFile image mode=...    26        1     1
# ...                                                 ...   ...      ...   ...
# 9775  <PIL.JpegImagePlugin.JpegImageFile image mode=...    16        1     0
# 9776  <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     3
# 9777  <PIL.JpegImagePlugin.JpegImageFile image mode=...    71        0     0
# 9778  <PIL.JpegImagePlugin.JpegImageFile image mode=...    54        0     0
# 9779  <PIL.JpegImagePlugin.JpegImageFile image mode=...    36        0     0
#
# [9780 rows x 4 columns]

# %%
Race_0 = df[df["Race"] == 0]

# %%
Race_0
# Out:
#                                                  Images  Ages  Genders  Race
# 2     <PIL.JpegImagePlugin.JpegImageFile image mode=...    16        0     0
# 6     <PIL.JpegImagePlugin.JpegImageFile image mode=...    53        1     0
# 8     <PIL.JpegImagePlugin.JpegImageFile image mode=...    37        0     0
# 11    <PIL.JpegImagePlugin.JpegImageFile image mode=...    52        0     0
# 12    <PIL.JpegImagePlugin.JpegImageFile image mode=...    18        1     0
# ...                                                 ...   ...      ...   ...
# 9774  <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     0
# 9775  <PIL.JpegImagePlugin.JpegImageFile image mode=...    16        1     0
# 9777  <PIL.JpegImagePlugin.JpegImageFile image mode=...    71        0     0
# 9778  <PIL.JpegImagePlugin.JpegImageFile image mode=...    54        0     0
# 9779  <PIL.JpegImagePlugin.JpegImageFile image mode=...    36        0     0
#
# [5265 rows x 4 columns]

# %%
Race_1 = df[df["Race"] == 1]

# %%
Race_1
# Out:
#                                                  Images  Ages  Genders  Race
# 4     <PIL.JpegImagePlugin.JpegImageFile image mode=...    26        1     1
# 9     <PIL.JpegImagePlugin.JpegImageFile image mode=...    10        0     1
# 33    <PIL.JpegImagePlugin.JpegImageFile image mode=...     5        1     1
# 41    <PIL.JpegImagePlugin.JpegImageFile image mode=...    96        1     1
# 63    <PIL.JpegImagePlugin.JpegImageFile image mode=...    26        1     1
# ...                                                 ...   ...      ...   ...
# 9674  <PIL.JpegImagePlugin.JpegImageFile image mode=...    26        0     1
# 9695  <PIL.JpegImagePlugin.JpegImageFile image mode=...    65        1     1
# 9699  <PIL.JpegImagePlugin.JpegImageFile image mode=...     8        1     1
# 9710  <PIL.JpegImagePlugin.JpegImageFile image mode=...    10        0     1
# 9763  <PIL.JpegImagePlugin.JpegImageFile image mode=...    75        0     1
#
# [406 rows x 4 columns]

# %%
Race_2 = df[df["Race"] == 2]

# %%
Race_2
# Out:
#                                                  Images  Ages  Genders  Race
# 0     <PIL.JpegImagePlugin.JpegImageFile image mode=...     9        1     2
# 1     <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     2
# 5     <PIL.JpegImagePlugin.JpegImageFile image mode=...     2        0     2
# 10    <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        0     2
# 18    <PIL.JpegImagePlugin.JpegImageFile image mode=...    24        1     2
# ...                                                 ...   ...      ...   ...
# 9754  <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        0     2
# 9757  <PIL.JpegImagePlugin.JpegImageFile image mode=...    46        1     2
# 9765  <PIL.JpegImagePlugin.JpegImageFile image mode=...    86        1     2
# 9766  <PIL.JpegImagePlugin.JpegImageFile image mode=...    28        0     2
# 9770  <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     2
#
# [1553 rows x 4 columns]

# %%
Race_3 = df[df["Race"] == 3]

# %%
Race_3
# Out:
#                                                  Images  Ages  Genders  Race
# 3     <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     3
# 13    <PIL.JpegImagePlugin.JpegImageFile image mode=...    34        1     3
# 17    <PIL.JpegImagePlugin.JpegImageFile image mode=...    75        1     3
# 20    <PIL.JpegImagePlugin.JpegImageFile image mode=...     3        0     3
# 30    <PIL.JpegImagePlugin.JpegImageFile image mode=...     5        1     3
# ...                                                 ...   ...      ...   ...
# 9743  <PIL.JpegImagePlugin.JpegImageFile image mode=...    55        1     3
# 9745  <PIL.JpegImagePlugin.JpegImageFile image mode=...    24        1     3
# 9760  <PIL.JpegImagePlugin.JpegImageFile image mode=...    21        0     3
# 9771  <PIL.JpegImagePlugin.JpegImageFile image mode=...    19        1     3
# 9776  <PIL.JpegImagePlugin.JpegImageFile image mode=...     1        1     3
#
# [1453 rows x 4 columns]

# %%
Non_caucasien = len(Race_1) + len(Race_2) + len(Race_3)  
Caucasien = len(Race_0)

# %%
Non_caucasien
# Out:
# 3412

# %%
Caucasien
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w7/fs9tw0cx6pbfr2z0lwnhcc7h0000gn/T/ipykernel_92485/1621044147.py in <module>
# ----> 1 Caucasien
#
# NameError: name 'Caucasien' is not defined
