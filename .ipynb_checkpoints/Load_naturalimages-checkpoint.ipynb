# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
import cv2
import dlib
from time import time
import matplotlib.pyplot as plt
import copy
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')
import re

# %%
path = '/Users/laurabraadrasmussen/Bachelorprojekt/Data/archive/natural_images/flower/'


images = [Image.open(path + i).copy() for i in tqdm(os.listdir(path))]
# Out:
#   0%|          | 0/843 [00:00<?, ?it/s]

# %%
df_natural = pd.DataFrame({'Images': images, 'Label': 0, 'Folder':'Flower' })

# %%
df_natural
# Out:
#                                                 Images  Label  Folder
# 0    <PIL.Image.Image image mode=RGB size=499x367 a...      0  Flower
# 1    <PIL.Image.Image image mode=RGB size=148x209 a...      0  Flower
# 2    <PIL.Image.Image image mode=RGB size=158x111 a...      0  Flower
# 3    <PIL.Image.Image image mode=RGB size=443x307 a...      0  Flower
# 4    <PIL.Image.Image image mode=RGB size=170x97 at...      0  Flower
# ..                                                 ...    ...     ...
# 838  <PIL.Image.Image image mode=RGB size=648x537 a...      0  Flower
# 839  <PIL.Image.Image image mode=RGB size=327x320 a...      0  Flower
# 840  <PIL.Image.Image image mode=RGB size=353x219 a...      0  Flower
# 841  <PIL.Image.Image image mode=RGB size=639x465 a...      0  Flower
# 842  <PIL.Image.Image image mode=RGB size=845x579 a...      0  Flower
#
# [843 rows x 3 columns]

# %%
df = pd.read_pickle("/Users/laurabraadrasmussen/Bachelorprojekt/df_equal.pkl")

# %%
df
# Out:
#                                                  Images  Ages  Genders  Race  \
# 0     <PIL.Image.Image image mode=RGB size=906x903 a...    50        0     0
# 1     <PIL.Image.Image image mode=RGB size=690x1015 ...    27        0     0
# 2     <PIL.Image.Image image mode=RGB size=280x350 a...    85        1     0
# 3     <PIL.Image.Image image mode=RGB size=1202x675 ...    51        1     0
# 4     <PIL.Image.Image image mode=RGB size=590x727 a...    34        1     0
# ...                                                 ...   ...      ...   ...
# 9995  <PIL.Image.Image image mode=RGB size=290x359 a...    30        0     3
# 9996  <PIL.Image.Image image mode=RGB size=466x695 a...    29        0     3
# 9997  <PIL.Image.Image image mode=RGB size=552x367 a...    34        1     3
# 9998  <PIL.Image.Image image mode=RGB size=306x457 a...    53        0     3
# 9999  <PIL.Image.Image image mode=RGB size=906x903 a...    42        0     3
#
#       Caucasien/Non-caucasian
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 9995                        1
# 9996                        1
# 9997                        1
# 9998                        1
# 9999                        1
#
# [10000 rows x 5 columns]

# %%
df['Label'] = 1

# %%
df_w_natural= pd.concat([df, df_natural], ignore_index = True, join = 'outer')

# %%
df_w_natural
# Out:
#                                                   Images  Ages  Genders  Race  \
# 0      <PIL.Image.Image image mode=RGB size=402x469 a...  51.0      0.0   3.0
# 1      <PIL.Image.Image image mode=RGB size=487x476 a...   NaN      NaN   NaN
# 2      <PIL.Image.Image image mode=RGB size=620x412 a...  68.0      0.0   0.0
# 3      <PIL.Image.Image image mode=RGB size=282x419 a...  61.0      0.0   0.0
# 4      <PIL.Image.Image image mode=RGB size=742x1099 ...  20.0      0.0   0.0
# ...                                                  ...   ...      ...   ...
# 10838  <PIL.Image.Image image mode=RGB size=822x819 a...  34.0      1.0   1.0
# 10839  <PIL.Image.Image image mode=RGB size=354x529 a...  72.0      1.0   3.0
# 10840  <PIL.Image.Image image mode=RGB size=738x1103 ...  60.0      0.0   2.0
# 10841  <PIL.Image.Image image mode=RGB size=392x300 a...  21.0      1.0   2.0
# 10842  <PIL.Image.Image image mode=RGB size=274x353 a...  65.0      0.0   3.0
#
#        Caucasien/Non-caucasian  Label  Folder
# 0                          1.0      1     NaN
# 1                          NaN      0  Flower
# 2                          0.0      1     NaN
# 3                          0.0      1     NaN
# 4                          0.0      1     NaN
# ...                        ...    ...     ...
# 10838                      1.0      1     NaN
# 10839                      1.0      1     NaN
# 10840                      1.0      1     NaN
# 10841                      1.0      1     NaN
# 10842                      1.0      1     NaN
#
# [10843 rows x 7 columns]

# %%
df_w_natural = df_w_natural.sample(frac = 1).reset_index(drop = True)

# %%
df_w_natural.to_pickle("df_w_natural.pkl")
