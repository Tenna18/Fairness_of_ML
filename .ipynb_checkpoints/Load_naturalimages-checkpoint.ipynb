# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
import cv2
import dlib
from time import time
import matplotlib.pyplot as plt
import copy
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')
import re

# %%
path = '/Users/laurabraadrasmussen/Bachelorprojekt/Data/archive/natural_images/'

Images = []
Folder = []
for i in os.listdir(path):
    for j in (os.listdir(os.path.join(path, i))):
        im = Image.open(os.path.join(os.path.join(path, i), j))
        Images.append(im.copy())
        Folder.append(i)
        im.close()
        
        
#images = [Image.open(path + i).copy() for i in tqdm(os.listdir(path))]

# %%
len(Folder)
# Out:
# 5913

# %%
df_natural = pd.DataFrame({'Images': Images, 'Label': 0, 'Folder': Folder })

# %%
df_natural
# Out:
#                                                  Images  Label    Folder
# 0     <PIL.Image.Image image mode=RGB size=163x175 a...      0       cat
# 1     <PIL.Image.Image image mode=RGB size=429x368 a...      0       cat
# 2     <PIL.Image.Image image mode=RGB size=442x363 a...      0       cat
# 3     <PIL.Image.Image image mode=RGB size=444x324 a...      0       cat
# 4     <PIL.Image.Image image mode=RGB size=314x490 a...      0       cat
# ...                                                 ...    ...       ...
# 5908  <PIL.Image.Image image mode=RGB size=290x83 at...      0  airplane
# 5909  <PIL.Image.Image image mode=RGB size=292x109 a...      0  airplane
# 5910  <PIL.Image.Image image mode=RGB size=298x63 at...      0  airplane
# 5911  <PIL.Image.Image image mode=RGB size=291x108 a...      0  airplane
# 5912  <PIL.Image.Image image mode=RGB size=291x86 at...      0  airplane
#
# [5913 rows x 3 columns]

# %%
df = pd.read_pickle("/Users/laurabraadrasmussen/Bachelorprojekt/df_equal.pkl")

# %%
df
# Out:
#                                                  Images  Ages  Genders  Race  \
# 0     <PIL.Image.Image image mode=RGB size=906x903 a...    50        0     0
# 1     <PIL.Image.Image image mode=RGB size=690x1015 ...    27        0     0
# 2     <PIL.Image.Image image mode=RGB size=280x350 a...    85        1     0
# 3     <PIL.Image.Image image mode=RGB size=1202x675 ...    51        1     0
# 4     <PIL.Image.Image image mode=RGB size=590x727 a...    34        1     0
# ...                                                 ...   ...      ...   ...
# 9995  <PIL.Image.Image image mode=RGB size=290x359 a...    30        0     3
# 9996  <PIL.Image.Image image mode=RGB size=466x695 a...    29        0     3
# 9997  <PIL.Image.Image image mode=RGB size=552x367 a...    34        1     3
# 9998  <PIL.Image.Image image mode=RGB size=306x457 a...    53        0     3
# 9999  <PIL.Image.Image image mode=RGB size=906x903 a...    42        0     3
#
#       Caucasien/Non-caucasian  Label  Folder
# 0                           0      1  Person
# 1                           0      1  Person
# 2                           0      1  Person
# 3                           0      1  Person
# 4                           0      1  Person
# ...                       ...    ...     ...
# 9995                        1      1  Person
# 9996                        1      1  Person
# 9997                        1      1  Person
# 9998                        1      1  Person
# 9999                        1      1  Person
#
# [10000 rows x 7 columns]

# %%
df['Label'] = 1
df['Folder'] = 'Person'

# %%
df_w_natural= pd.concat([df, df_natural], ignore_index = True, join = 'outer')

# %%
df_w_natural
# Out:
#                                                   Images  Ages  Genders  Race  \
# 0      <PIL.Image.Image image mode=RGB size=230x196 a...   NaN      NaN   NaN
# 1      <PIL.Image.Image image mode=RGB size=359x300 a...   3.0      1.0   0.0
# 2      <PIL.Image.Image image mode=RGB size=485x266 a...   NaN      NaN   NaN
# 3      <PIL.Image.Image image mode=RGB size=754x1079 ...  28.0      0.0   1.0
# 4      <PIL.Image.Image image mode=RGB size=806x803 a...  39.0      0.0   2.0
# ...                                                  ...   ...      ...   ...
# 15908  <PIL.Image.Image image mode=RGB size=190x105 a...   NaN      NaN   NaN
# 15909  <PIL.Image.Image image mode=RGB size=1106x735 ...  30.0      0.0   1.0
# 15910  <PIL.Image.Image image mode=RGB size=486x723 a...  28.0      1.0   2.0
# 15911  <PIL.Image.Image image mode=RGB size=4000x5996...  72.0      1.0   0.0
# 15912  <PIL.Image.Image image mode=RGB size=368x553 a...  22.0      1.0   3.0
#
#        Caucasien/Non-caucasian  Label     Folder
# 0                          NaN      0     flower
# 1                          0.0      1     Person
# 2                          NaN      0     flower
# 3                          1.0      1     Person
# 4                          1.0      1     Person
# ...                        ...    ...        ...
# 15908                      NaN      0  motorbike
# 15909                      1.0      1     Person
# 15910                      1.0      1     Person
# 15911                      0.0      1     Person
# 15912                      1.0      1     Person
#
# [15913 rows x 7 columns]

# %%
df_w_natural = df_w_natural.sample(frac = 1).reset_index(drop = True)

# %%
df_w_natural.to_pickle("df_w_natural.pkl")
